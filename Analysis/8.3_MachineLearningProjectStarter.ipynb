# %%
data1 = pd.read_csv(r"C:\Users\Gk\Documents\dev\data\LinearRegression_Football_data\df_ols_all.csv", encoding='utf-8')
data1
# Out:
#      Unnamed: 0  position        age      height     weight    rating  value  \
# 0             0  2.000000  25.000000  184.000000  78.000000  2.333333   20.0
# 1             1  3.000000  21.000000  190.000000  75.000000  4.777778   31.5
# 2             2  4.000000  27.000000  181.000000  72.000000  5.250000   32.0
# 3             3  3.000000  24.000000  188.000000  78.000000  6.000000   24.0
# 4             4  4.000000  25.000000  171.000000  70.000000  7.000000   32.0
# ..          ...       ...        ...         ...        ...       ...    ...
# 465         467  3.769231  23.076923  188.230769  86.769231  1.615385   24.0
# 466         468  4.000000  32.000000  175.000000  77.000000  6.153846   22.5
# 467         469  3.000000  24.000000  176.000000  64.000000  3.333333   20.0
# 468         470  2.000000  27.000000  180.000000  71.000000  4.857143   22.5
# 469         471  3.000000  26.000000  195.000000  94.000000  6.125000   20.0
#
# ...

# %%
data2 = pd.read_csv(r"C:\Users\Gk\Documents\dev\data\LinearRegression_Football_data\df_visual.csv", encoding='utf-8')
data2
# Out:
#       Unnamed: 0  player_name  age  height  weight  rating  league  \
# 0              0  A. Kramaric   29     177      73       7   70.31
# 1              1  A. Kramaric   29     177      73       7   70.31
# 2              2  A. Kramaric   29     177      73       7   70.31
# 3              3  A. Kramaric   29     177      73       6   41.18
# 4              4  A. Kramaric   29     177      73       6   41.18
# ...          ...          ...  ...     ...     ...     ...     ...
# 3973        3973     R. Neves   23     180      80       7   41.18
# 3974        3974     R. Neves   23     180      80       7   41.18
# 3975        3975     R. Neves   23     180      80       7   41.18
# 3976        3976     R. Neves   23     180      80       0   41.18
# 3977        3977     R. Neves   23     180      80       7   41.18
#
#      nationality  value  follower  ...  penalty_commited  penalty_success  \
# 0        Croatia   30.5    351898  ...               0.0           0.1131
# ...

# %%
y = data2.value
y
# Out:
# 0       30.5
# 1       30.5
# 2       30.5
# 3       30.5
# 4       30.5
#         ...
# 3973    40.0
# 3974    40.0
# 3975    40.0
# 3976    40.0
# 3977    40.0
# Name: value, Length: 3978, dtype: float64

# %%
data2.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'age', 'height', 'weight', 'rating',
#        'league', 'nationality', 'value', 'follower', 'captain', 'shots_total',
#        'shots_on', 'goals_total', 'goals_conceded', 'goals_assists',
#        'passes_total', 'passes_key', 'passes_accuracy', 'tackles_total',
#        'tackles_blocks', 'tackles_interceptions', 'duels_total', 'duels_won',
#        'dribbles_attempts', 'dribbles_success', 'fouls_drawn',
#        'fouls_committed', 'cards_yellow', 'cards_yellowred', 'cards_red',
#        'penalty_won', 'penalty_commited', 'penalty_success', 'penalty_missed',
#        'penalty_saved', 'games_appearences', 'games_lineups', 'substitutes_in',
#        'substitutes_out', 'substitutes_bench', 'games_played'],
#       dtype='object')

# %%
pd.options.display.max_columns = len(data2.columns)

# %%
data2
# Out:
#       Unnamed: 0  player_name  age  height  weight  rating  league  \
# 0              0  A. Kramaric   29     177      73       7   70.31
# 1              1  A. Kramaric   29     177      73       7   70.31
# 2              2  A. Kramaric   29     177      73       7   70.31
# 3              3  A. Kramaric   29     177      73       6   41.18
# 4              4  A. Kramaric   29     177      73       6   41.18
# ...          ...          ...  ...     ...     ...     ...     ...
# 3973        3973     R. Neves   23     180      80       7   41.18
# 3974        3974     R. Neves   23     180      80       7   41.18
# 3975        3975     R. Neves   23     180      80       7   41.18
# 3976        3976     R. Neves   23     180      80       0   41.18
# 3977        3977     R. Neves   23     180      80       7   41.18
#
#      nationality  value  follower  captain  shots_total  shots_on  \
# 0        Croatia   30.5    351898   0.0000       3.3555    1.3950
# ...

# %%
data2.drop(['Unnamed: 0', 'player_name'], axis=1)
# Out:
#       age  height  weight  rating  league nationality  value  follower  \
# 0      29     177      73       7   70.31     Croatia   30.5    351898
# 1      29     177      73       7   70.31     Croatia   30.5    351898
# 2      29     177      73       7   70.31     Croatia   30.5    351898
# 3      29     177      73       6   41.18     Croatia   30.5    351898
# 4      29     177      73       6   41.18     Croatia   30.5    351898
# ...   ...     ...     ...     ...     ...         ...    ...       ...
# 3973   23     180      80       7   41.18    Portugal   40.0    413959
# 3974   23     180      80       7   41.18    Portugal   40.0    413959
# 3975   23     180      80       7   41.18    Portugal   40.0    413959
# 3976   23     180      80       0   41.18    Portugal   40.0    413959
# 3977   23     180      80       7   41.18    Portugal   40.0    413959
#
#       captain  shots_total  shots_on  goals_total  goals_conceded  \
# ...

# %%
data2.drop('nationality', axis=1)
# Out:
#       Unnamed: 0  player_name  age  height  weight  rating  league  value  \
# 0              0  A. Kramaric   29     177      73       7   70.31   30.5
# 1              1  A. Kramaric   29     177      73       7   70.31   30.5
# 2              2  A. Kramaric   29     177      73       7   70.31   30.5
# 3              3  A. Kramaric   29     177      73       6   41.18   30.5
# 4              4  A. Kramaric   29     177      73       6   41.18   30.5
# ...          ...          ...  ...     ...     ...     ...     ...    ...
# 3973        3973     R. Neves   23     180      80       7   41.18   40.0
# 3974        3974     R. Neves   23     180      80       7   41.18   40.0
# 3975        3975     R. Neves   23     180      80       7   41.18   40.0
# 3976        3976     R. Neves   23     180      80       0   41.18   40.0
# 3977        3977     R. Neves   23     180      80       7   41.18   40.0
#
#       follower  captain  shots_total  shots_on  goals_total  goals_conceded  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit_transform(data2)
